# %%
import os
import cv2

# %%
filenames= os.listdir (".")

path = 'dataset/1'
x=0
for files in os.listdir(path):
    if files.endswith('.png'):
        read =cv2.imread('dataset/1/%s' %files)
        cv2.imwrite('1_%s.png' %x,read)
        x+=1
        print ("\nFile #" + str(x) + ": " + files)
print (x)
print(read)
# Out:
# File #1: 0_20.png
#
# File #2: 0_3.png
#
# File #3: 0_38.png
#
# File #4: 0_9.png
#
# File #5: 0_40.png
#
# File #6: 0_18.png
#
# File #7: 0_49.png
#
# File #8: 0_30.png
#
# File #9: 0_45.png
#
# File #10: 0_93.png
#
# File #11: 0_15.png
#
# File #12: 0_29.png
#
# File #13: 0_99.png
#
# File #14: 0_65.png
#
# File #15: 0_8.png
#
# File #16: 0_28.png
#
# File #17: 0_14.png
#
# File #18: 0_66.png
#
# File #19: 0_17.png
#
# File #20: 0_22.png
#
# File #21: 0_83.png
#
# File #22: 0_39.png
#
# File #23: 0_53.png
#
# File #24: 0_89.png
#
# File #25: 0_35.png
#
# File #26: 0_62.png
#
# File #27: 0_6.png
#
# File #28: 0_7.png
#
# File #29: 0_25.png
#
# File #30: 0_75.png
#
# File #31: 0_95.png
#
# File #32: 0_86.png
#
# File #33: 0_73.png
#
# File #34: 0_4.png
#
# File #35: 0_50.png
#
# File #36: 0_64.png
#
# File #37: 0_5.png
#
# File #38: 0_76.png
#
# File #39: 0_63.png
#
# File #40: 0_12.png
#
# File #41: 0_71.png
#
# File #42: 0_82.png
#
# File #43: 0_2.png
#
# File #44: 0_57.png
#
# ...

# %%
print(ord('0'))
# Out:
# 48
